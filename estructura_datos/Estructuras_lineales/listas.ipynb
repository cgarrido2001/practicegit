# %% [markdown]
# ![image.png](attachment:ee551c99-46a3-4d75-9d15-b5f2089efa05.png)
# ![image.png](attachment:c46f805f-c303-4ae3-a62e-cb6b92445453.png)
# ![image.png](attachment:fe6d511b-083f-44cb-9b66-afca57a4349d.png)
